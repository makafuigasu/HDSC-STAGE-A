# %%
#importing numpy and pandas libraries
import numpy as np
import pandas as pd

# %%
#importing csv dataset
df=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding='latin-1')

# %%
df.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
#finding the sum of column 2014 and 2017
df.groupby(['Y2014', 'Y2017']).sum()
# Out:
#                      Area Code  Item Code  Element Code     Y2015     Y2016  \
# Y2014     Y2017
# -1796.0    0.0             159       2657          5072     -73.0     -12.0
# -1631.0   -689.0           159       2924          5072       6.0     -77.0
# -849.0    -600.0           266       5444         10340   -1118.0   -1119.0
# -838.0    -538.0           184       2907          5072    -827.0    -679.0
# -685.0     689.0           143       2905          5072    3418.0   -3225.0
# ...                        ...        ...           ...       ...       ...
#  90425.0   96443.0          59       2501           511   92443.0   94447.0
#  98094.0   106400.0        238       2501           511  100835.0  103603.0
#  108756.0  112625.0        159       2907          5301  110798.0  116483.0
#  109593.0  117702.0        159       2907          5511  111663.0  119330.0
#  176405.0  190873.0        159       2501           511  181137.0  185960.0
#
#                         Y2018
# ...

# %%
df.groupby(['Y2015']).mean()
# Out:
#            Area Code  Item Code  Element Code     Y2014     Y2016     Y2017  \
# Y2015
# -3161.0        202.0     2905.0        5072.0     439.0   -1499.0    2665.0
# -2152.0        202.0     2514.0        5072.0     626.0   -1324.0    2555.0
# -1284.0        276.0     2905.0        5072.0    4569.0    3266.0    -607.0
# -907.0         251.0     2905.0        5072.0     520.0    -506.0     532.0
# -887.0         276.0     2518.0        5072.0    3134.0    2432.0    -819.0
# ...              ...        ...           ...       ...       ...       ...
#  92443.0        59.0     2501.0         511.0   90425.0   94447.0   96443.0
#  100835.0      238.0     2501.0         511.0   98094.0  103603.0  106400.0
#  110798.0      159.0     2907.0        5301.0  108756.0  116483.0  112625.0
#  111663.0      159.0     2907.0        5511.0  109593.0  119330.0  117702.0
#  181137.0      159.0     2501.0         511.0  176405.0  185960.0  190873.0
#
#               Y2018
# Y2015
# ...

# %%
df.groupby(['Y2015']).std()
# Out:
#            Area Code  Item Code  Element Code  Y2014  Y2016  Y2017  Y2018
# Y2015
# -3161.0          NaN        NaN           NaN    NaN    NaN    NaN    NaN
# -2152.0          NaN        NaN           NaN    NaN    NaN    NaN    NaN
# -1284.0          NaN        NaN           NaN    NaN    NaN    NaN    NaN
# -907.0           NaN        NaN           NaN    NaN    NaN    NaN    NaN
# -887.0           NaN        NaN           NaN    NaN    NaN    NaN    NaN
# ...              ...        ...           ...    ...    ...    ...    ...
#  92443.0         NaN        NaN           NaN    NaN    NaN    NaN    NaN
#  100835.0        NaN        NaN           NaN    NaN    NaN    NaN    NaN
#  110798.0        NaN        NaN           NaN    NaN    NaN    NaN    NaN
#  111663.0        NaN        NaN           NaN    NaN    NaN    NaN    NaN
#  181137.0        NaN        NaN           NaN    NaN    NaN    NaN    NaN
#
# [4520 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
#checking for correlation among the years with element code column
plt.scatter('Element code', 'Y2014')
plt.show()

# %%
plt.scatter('element code', 'Y2015')
plt.show()

# %%
plt.scatter('element code', 'Y2016')
plt.show()

# %%
plt.scatter('element code', 'Y2017')
plt.show()

# %%
plt.scatter('element code', 'Y2018')
plt.show()
